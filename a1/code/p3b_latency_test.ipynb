# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('p3b_insert.csv')
ax = df.plot(style=".-", figsize=(15, 10))
plt.grid()
plt.show()

# %%
df = pd.read_csv('p3b_search.csv')
ax = df.plot(style=".-", figsize=(15, 10))
plt.grid()
plt.show()
