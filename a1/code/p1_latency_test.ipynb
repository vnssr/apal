# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('p1_append.csv')
ax = df.plot(style=".-", figsize=(15, 10))
ax.set_yticks(np.arange(0, 30000, 2000))
plt.grid()
plt.show()

# %%
df['HAT'].median()
# Out:
# 96.0

# %%
df['Vector'].median()
# Out:
# 260.0

# %%
df = pd.read_csv('p1_access.csv')
ax = df.plot(style=".-", figsize=(15, 10))
ax.set_yticks(np.arange(0, 1000, 100))
plt.grid()
plt.show()

# %%
df['HAT'].median()
# Out:
# 96.0

# %%
df['Vector'].median()
# Out:
# 232.0

# %%
df = pd.read_csv('p1_scan.csv')
ax = df.plot(style=".-", figsize=(15, 10))
ax.set_yticks(np.arange(1500, 2800, 100))
plt.grid()
plt.show()

# %%
df['HAT'].median()
# Out:
# 1864.0

# %%
df['Vector'].median()
# Out:
# 2036.0
