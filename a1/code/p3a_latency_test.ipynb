# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('p3a_insert.csv')
ax = df.plot(style=".-", figsize=(15, 10))
ax.set_yticks(np.arange(1000, 20000, 2000))
plt.grid()
plt.show()

# %%
df = pd.read_csv('p3a_search.csv')
ax = df.plot(style=".-", figsize=(15, 10))
plt.grid()
plt.show()
